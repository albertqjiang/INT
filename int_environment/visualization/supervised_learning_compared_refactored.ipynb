# %%
import json
import os
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np
import math
import seaborn as sns
sns.set()
sns.set_style("darkgrid")

# %%
def moving_average(input_list, gamma=0):
    output_list = list()
    ma = input_list[0]
    for element in input_list:
        ma = gamma * ma + (1-gamma) * element
        output_list.append(ma)
    return output_list

# %%
def plot_eval(evals):
    for i, key in enumerate(evals.keys()):
        figure(num=None, figsize=(14, 10*len(evals)), dpi=80, facecolor='w', edgecolor='k')
        ax = plt.subplot(len(evals), 1, i+1)
        sorted_keys = sorted(list(evals[key]["eval"].keys()))
        sorted_values = [evals[key]["eval"][sorted_key] for sorted_key in sorted_keys]
        plt.bar(sorted_keys, sorted_values)
        plt.title(key+evals[key]["trained"]+" split: "+str(evals[key]["online_train_test_split"]))
        plt.ylim(0, 1)
        plt.show()

# %%
def plot_stuff(phonebook, file_names, title, val=False):
    linestyles = ['-', '--', '-.', ':']
    colours = ['tab:blue', 'tab:orange','tab:green','tab:red','tab:purple',
               'tab:brown','tab:pink','tab:gray','tab:olive','tab:cyan']
    group_by_index = dict()
    for dir_name, dir_index in phonebook.items():
        if dir_index in group_by_index:
            group_by_index[dir_index].append(dir_name)
        else:
            group_by_index[dir_index] = [dir_name]
    
    for i, dir_index in enumerate(group_by_index.keys()):
        figure(num=None, figsize=(14, 10*len(group_by_index)), dpi=80, facecolor='w', edgecolor='k')
        ax = plt.subplot(len(group_by_index), 1, i+1)
        
        for k, dir_name in enumerate(sorted(group_by_index[dir_index])):
            colour = colours[k]
            print(dir_name)
            try:
                record = json.load(open(os.path.join(dir_name, "record.json"), "r"))
                config = json.load(open(os.path.join(dir_name, "env_config.json"), "r"))
                for j, file_name in enumerate(file_names):
                    style = linestyles[j]
                    training_loss = record[file_name]
                    batch_size = config["batch_size"]
                    display_file_name = file_name.split("_")[0]

                    hyper_params = "bow" if config["bag_of_words"] else config["obs_mode"][:3]
                    if config["online"]:
                        hyper_params += \
                            ", online split: {}, epd {}, lr {}, {}".format(
                                config["online_train_test_split"], config["epochs_per_online_dataset"],
                                config["lr"], "Forward" if "forward" in dir_name else "Backward"
                            )
                    print(dir_index, hyper_params, record["progress"])
                    if val=="val":
                        for key, loss in training_loss.items():
                            hor_axis = np.array(range(len(loss)))
                            quantity_to_plot = moving_average(loss)
                            plt.plot(hor_axis, quantity_to_plot, label=hyper_params+"(diff: {})".format(key))
                            ax.annotate(round(quantity_to_plot[-1], 2), 
                                        xy=(hor_axis[-1], quantity_to_plot[-1]),
                                       linestyle=style,
                                       color=colour)
                    elif val=="succ":
                        if isinstance(training_loss, list):
                            hor_axis = np.array(range(len(training_loss))) * \
                                config["epoch_per_case_record"] * config["problems"]
                            quantity_to_plot = moving_average(training_loss, 0.97)
                            plt.plot(hor_axis, quantity_to_plot, label=hyper_params+" "+display_file_name,
                                       linestyle=style,
                                       color=colour)
                            ax.annotate(round(quantity_to_plot[-1], 2), 
                                        xy=(hor_axis[-1], quantity_to_plot[-1]))
                        else:
                            for key, loss in training_loss.items():
                                hor_axis = np.array(range(len(loss))) \
                                    * config["epoch_per_case_record"] * config["problems"]
                                quantity_to_plot = moving_average(loss)
                                plt.plot(hor_axis, quantity_to_plot, label=hyper_params+"(diff: {})".format(key),
                                       linestyle=style,
                                       color=colour)
                                ax.annotate(round(quantity_to_plot[-1], 2), 
                                            xy=(hor_axis[-1], quantity_to_plot[-1]))
                                print(key, round(quantity_to_plot[-1], 2))
                    else:
                        quantity_to_plot = moving_average(np.array(training_loss))
                        hor_axis = np.array(range(len(training_loss))) * config["problems"]
                        plt.plot(hor_axis, quantity_to_plot, label=hyper_params,
                                       linestyle=style,
                                       color=colour)
                        ax.annotate(round(quantity_to_plot[-1], 2), 
                                    xy=(hor_axis[-1], quantity_to_plot[-1]))
            except Exception as e:
                print(dir_name)
                print("Exception: {}".format(e))
                pass
        plt.legend()
        plt.xlabel("Problems trained")
        
        ax.set_title("{}: {}".format(title, dir_index))
        plt.show()

# %%
directory = "/scratch/hdd001/home/ajiang/pt_models/sl_backward_basic"
dir_phonebook = dict()
dir_evals = dict()
for dir_name in os.listdir(directory):
    if os.path.isdir(os.path.join(directory, dir_name)) and (not dir_name.startswith('.')):
        if "2020_01_16" < dir_name:
            config = json.load(open(os.path.join(directory, dir_name, "env_config.json"), "r"))
            config_index = config['train_dirs']
            if isinstance(config_index, list):
                train_index = ", ".join([single_index.split("/")[-1] for single_index in config_index])
                test_index = ", ".join([single_index.split("/")[-1] for single_index in config["test_dirs"]])
            online = config["online"]
            if online:
                actual_l_train = int((int(str(config["train_dirs"])[-3]) + 1) / 2)
                train_config = str(config["train_dirs"])[:-3] + str(actual_l_train) + str(config["train_dirs"])[-2:]
                actual_l_test = int((int(str(config["test_dirs"])[-3]) + 1) / 2)
                test_config = str(config["test_dirs"])[:-3] + str(actual_l_test) + str(config["test_dirs"])[-2:]
                print(train_config, test_config)
#                 train_config, test_config = config["train_dirs"], config["test_dirs"]
                dir_phonebook[os.path.join(directory, dir_name)] = \
                    "Trained on {} and tested on: {}".format(train_config, test_config)
            else:
                dir_phonebook[os.path.join(directory, dir_name)] = \
                    "Trained on: {}; Tested on: {}".format(train_index, test_index)
            
            dir_evals[dir_name] = {
                "trained": "k={}, l={}".format(config["axioms"], config["length"]),
                "online_train_test_split": config["online_train_test_split"],
                "eval": {}
            }
            for eval_name in os.listdir(os.path.join(directory, dir_name)):
                if eval_name.startswith("k"):
                    sr = json.load(open(os.path.join(directory, dir_name, eval_name), "r"))
                    dir_evals[dir_name]["eval"][eval_name.split(".")[0]] = sr
                    
configs = dict()
for dir_name in dir_phonebook:
    config = json.load(open(os.path.join(dir_name, "env_config.json"), "r"))
    if "gnn_type" in config and "hidden_layers" in config:
        configs[dir_name.split("/")[2]] = {
            "learning rate": config["lr"],
            "epoch": config["epoch"],
            "state dimension": config["state_dim"],
            "batch size": config["batch_size"],
            "problem index": "{}-{}".format(config["train_val_diffs"][0], config["train_val_diffs"][-1]),
            "gnn_type": config["gnn_type"],
            "lr_decay": config["lr_decay"],
            "hidden_layers": config["hidden_layers"],
            "train_val_diffs": config["train_val_diffs"],
            "test_diffs": config["test_diffs"]
        }
config_df = pd.DataFrame(configs)
config_df.sort_index(axis=1, inplace=True)
# Out:
# ['k=2_l=3'] ['k=2_l=3']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=4_l=5'] ['k=4_l=5']
# ['k=3_l=3'] ['k=3_l=3']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=4_l=4'] ['k=4_l=4']
# ['k=2_l=2'] ['k=2_l=2']
# ['k=3_l=4'] ['k=3_l=4']
# ['k=2_l=3'] ['k=2_l=3']
# ['k=3_l=3'] ['k=3_l=3']

# %%
from copy import deepcopy
forward_book = deepcopy(dir_phonebook)

# %%
plot_stuff(dir_phonebook, ["train_losses"], "Training cross entropy: lemma and entities")
# Out:
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_31_08_861209
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 2.951%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_36_38_929175
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.319%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_37_44_960572
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.319%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_47_28_167691
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 2.866%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_34_939832
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.23900000000000002%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_36_243697
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.248%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_07_867772
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 1.1900000000000002%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_35_193483
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_35_193483
# Exception: Expecting value: line 1 column 1 (char 0)
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_37_08_846427
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_37_08_846427
# Exception: [Errno 2] No such file or directory: '/scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_37_08_846427/record.json'
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_01_16_213200
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_01_16_213200
# Exception: [Errno 2] No such file or directory: '/scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_01_16_213200/record.json'
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_20_47_319345
# Trained on ['k=3_l=7'] and tested on: ['k=3_l=7'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.039%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_21_44_315728
# Trained on ['k=3_l=7'] and tested on: ['k=3_l=7'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 0.13899999999999998%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_37_38_926291
# Trained on ['k=3_l=7'] and tested on: ['k=3_l=7'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.13899999999999998%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_34_811911
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_34_811911
# Exception: [Errno 2] No such file or directory: '/scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_34_811911/record.json'
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_35_844964
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_35_844964
# Exception: [Errno 2] No such file or directory: '/scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_35_844964/record.json'
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_51_40_555280
# Trained on ['k=3_l=7'] and tested on: ['k=3_l=7'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.01%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_53_09_096176
# Trained on ['k=3_l=7'] and tested on: ['k=3_l=7'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 0.039%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_17_24_19_516517
# Trained on ['k=3_l=7'] and tested on: ['k=3_l=7'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.039%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_32_39_379722
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_32_39_379722
# Exception: [Errno 2] No such file or directory: '/scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_32_39_379722/record.json'
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_37_08_755658
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_37_08_755658
# Exception: [Errno 2] No such file or directory: '/scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_37_08_755658/record.json'
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_33_51_184571
# Trained on ['k=4_l=9'] and tested on: ['k=4_l=9'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.06899999999999999%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_37_03_015504
# Trained on ['k=4_l=9'] and tested on: ['k=4_l=9'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 0.059000000000000004%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_05_880097
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_05_880097
# Exception: [Errno 2] No such file or directory: '/scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_05_880097/record.json'
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_06_052569
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_06_052569
# Exception: [Errno 2] No such file or directory: '/scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_06_052569/record.json'
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_53_10_698567
# Trained on ['k=4_l=9'] and tested on: ['k=4_l=9'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.219%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_53_10_699786
# Trained on ['k=4_l=9'] and tested on: ['k=4_l=9'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 0.06899999999999999%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_33_11_026487
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.213%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_36_10_512688
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.213%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_00_46_942852
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 1.169%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_01_47_361582
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 1.119%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_34_846806
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.124%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_34_855263
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.123%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_05_742921
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.7060000000000001%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_31_51_523469
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 0.679%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_30_40_437526
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.159%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_32_39_052529
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.159%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_23_47_118191
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.6890000000000001%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_32_43_903894
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 0.681%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_35_848980
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.06%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_35_866239
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.059000000000000004%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_53_10_888589
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 0.404%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_53_10_902668
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.40299999999999997%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_29_37_589098
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.213%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_34_38_121901
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.213%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_10_24_935240
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 1.574%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_19_28_663454
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 1.229%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_34_811657
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.127%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_37_167615
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.149%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_36_35_914721
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 0.5369999999999999%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_40_38_721635
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 0.6689999999999999%

# %%
plot_stuff(dir_phonebook, ["train_lemma_accs"], "Training lemma accuracies")

# %%
plot_stuff(dir_phonebook, ["test_lemma_accs"], "Test lemma accuracies")

# %%
plot_stuff(dir_phonebook, ["train_ent_accs"], "Training entity accuracies")

# %%
plot_stuff(dir_phonebook, ["test_ent_accs"], "Test entity accuracies")

# %%
plot_stuff(dir_phonebook, ["train_first_success_rates"], 
           "Training success rate", val="succ")
# Out:
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_771082
# Trained on ['k=4_l=9'] and tested on: ['k=4_l=9'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.128%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_901063
# Trained on ['k=4_l=9'] and tested on: ['k=4_l=9'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.11399999999999999%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_744052
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.22300000000000003%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_847392
# Trained on ['k=4_l=7'] and tested on: ['k=4_l=7'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.2%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_665684
# Trained on ['k=3_l=7'] and tested on: ['k=3_l=7'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.27699999999999997%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_698475
# Trained on ['k=3_l=7'] and tested on: ['k=3_l=7'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.233%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_618745
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 1.2%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_766425
# Trained on ['k=2_l=5'] and tested on: ['k=2_l=5'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 1.189%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_605467
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.5479999999999999%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_759221
# Trained on ['k=3_l=5'] and tested on: ['k=3_l=5'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.5459999999999999%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_775242
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 2.669%
# /scratch/hdd001/home/ywu/ineqResultsEasy/sl_back_basic/2019_11_27_03_50_30_795069
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 2.7289999999999996%

# %%
plot_stuff(dir_phonebook, ["test_first_success_rates"], 
           "Success rate", val="succ")

# %%
plot_stuff(dir_phonebook, ["train_first_success_rates", "test_first_success_rates"], 
           "Success rate", val="succ")
# Out:
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_33_11_026487
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.213%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.213%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_10_36_10_512688
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.213%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.213%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_00_46_942852
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 2.1270000000000002%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 2.1270000000000002%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_11_01_47_361582
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 2.1270000000000002%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 2.1270000000000002%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_34_846806
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.213%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0003, Backward 0.213%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_24_34_855263
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.213%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 30, lr 0.0001, Backward 0.213%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_25_05_742921
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 2.1270000000000002%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 2.1270000000000002%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_15_31_51_523469
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 2.1270000000000002%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 2.1270000000000002%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_20_43_56_413944
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 3.179%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0003, Backward 3.179%
# /scratch/hdd001/home/ajiang/pt_models/sl_backward_basic/2020_01_16_20_43_56_672581
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 3.109%
# Trained on ['k=2_l=3'] and tested on: ['k=2_l=3'] geo, online split: 0.9, epd 10, lr 0.0001, Backward 3.109%
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-1bd4d814e8ae> in <module>
#       1 plot_stuff(dir_phonebook, ["train_first_success_rates", "test_first_success_rates"],
# ----> 2            "Success rate", val="succ")
#
# <ipython-input-38-f75e4a7f5fe8> in plot_stuff(phonebook, file_names, title, val)
#      15
#      16         for k, dir_name in enumerate(sorted(group_by_index[dir_index])):
# ---> 17             colour = colours[k]
#      18             print(dir_name)
#      19             try:
#
# IndexError: list index out of range
